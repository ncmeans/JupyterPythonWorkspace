# %%
dat=22
sat=44
vat=66

# %%
print(dat)
print(sat)
print(vat)
# Out:
# 22
# 44
# 66

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# dat        int     22
# sat        int     44
# vat        int     66
